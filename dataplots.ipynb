# %% [markdown]
# Plots morphological type, stellar mass, petrosian radius, u-r color, u-i color, distance, and metallicity of foreground galaxy in 55 galaxy pairs.

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *

# %%
x = ['E','S0/a','Sa','Sab','Sb','Sbc','Sc','Scd','Sd','Sdm','Sm']
y = [2,2,5,4,5,6,10,8,4,3,1]
y_theNine = [0,0,0,1,1,2,4,1,0,0,0]

x_pos = [i for i, _ in enumerate(x)]

plt.figure(figsize=(8,6))
plt.tick_params(labelsize=15)
plt.bar(x, y, color='red',alpha=0.4, edgecolor='black',linewidth=1)
plt.bar(x, y_theNine, color='w',alpha=0.9,hatch='xx', edgecolor='red',linewidth=1,label='STARSMOG Nine')
plt.xlabel("de Vaucouleurs class",fontsize=20)
plt.ylabel("Number of Foreground Galaxies",fontsize=20)
#plt.title("Morphological Type of Foreground Galaxy",fontsize=20)
plt.legend(loc=2, borderaxespad=0.,fontsize=15)

plt.xticks(x_pos, x)

plt.show()

# %% [markdown]
# The de Vaucouleurs morphological type of the foreground galaxy for our 55 overlapping galaxy pairs. The nine galaxy pairs to be inquired into are also indicated. This figure demonstrates the comprehensive range of galaxy morphologies spanned by the STARSMOG sample.

# %%
x = [6.88,8.41,8.69,9.24,9.31,9.33,9.36,9.45,9.48,9.54,9.56,9.58,9.65,9.88,9.93,9.94,
     9.96,9.99,10.07,10.09,10.11,10.14,10.16,10.19,10.24,10.25,10.26,10.30,10.30,10.42,
     10.45,10.46,10.50,10.56,10.57,10.64,10.67,10.72,10.79,10.80,10.82,10.84,10.84,
     10.88,10.88,11.04,11.09,11.30,11.52,11.61]
x_theNine = [10.88,9.88,11.04,10.84,10.07,10.57,10.80,9.54,11.30]
num_bins = 8
num_bins2 = 5
plt.figure(figsize=(8,6))
n, bins, patches = plt.hist(x, num_bins, color='green',alpha=0.4, edgecolor='black', linewidth=1)
n, bins, patches = plt.hist(x_theNine, num_bins2, color='w',hatch='xx', edgecolor='green', linewidth=1,label='STARSMOG Nine')
plt.tick_params(labelsize=15)
plt.xlabel("log$(M_*)$",fontsize=20)
plt.ylabel("Number of Foreground Galaxies",fontsize=20)
#plt.title("Stellar Mass of Foreground Galaxy",fontsize=20)
plt.legend(loc=2, borderaxespad=0.,fontsize=15)
plt.show()

# %% [markdown]
# Histogram of the stellar mass of the foreground galaxy for our 55 overlapping galaxy pairs. The nine galaxy pairs to be inquired into are also indicated. This figure demonstrates the broad range of galactic stellar mass spanned by the STARSMOG sample.

# %%
x = [1.50,3.54,3.86,4.44,5.74,7.15,7.32,7.43,7.66,7.83,8.21,8.32,8.88,
     9.54,9.59,10.05,10.84,11.01,11.16,11.21,11.39,12.43,12.89,13.40,
     13.59,13.82,13.99,14.37,14.42,14.78,16.25,16.65,16.75,17.54,18.02,
     18.19,20.07,20.74,21.63,22.22,22.57,24.85,25.03,25.17,26.27,34.22,
     40.18,43.77,48.72]
x_theNine=[22.22,10.05,7.66,5.74,16.25,20.07,13.59,13.40,13.82]
num_bins = 8
num_bins2 = 3
plt.figure(figsize=(8,6))
n, bins, patches = plt.hist(x, num_bins, color='blue',alpha=0.4, edgecolor='black', linewidth=1)
n, bins, patches = plt.hist(x_theNine, num_bins2, color='w',hatch='xx', edgecolor='blue', linewidth=1,label='STARSMOG Nine')
plt.tick_params(labelsize=15)
plt.xlabel("Petrosian Radius (arcsec)",fontsize=20)
plt.ylabel("Number of Foreground Galaxies",fontsize=20)
#plt.title("Petrosian Radius of Foreground Galaxy",fontsize=20)
plt.legend(loc=1, borderaxespad=0.,fontsize=15)
plt.show()

# %% [markdown]
# Histogram of the petrosian radius of the foreground galaxy for our 55 overlapping galaxy pairs. The nine galaxy pairs to be inquired into are also indicated. This figure demonstrates the broad range of foreground galaxy size spanned by the STARSMOG sample. Note that R_25 ~ 1.5 R_P (Conselice 2000) and R_P/R_E ~ 2.3 (Graham 2005).

# %%
#import pandas as pd
#from pandas import ExcelWriter
#from pandas import ExcelFile
#df = pd.read_excel('TargetsInfo_fromSDSS.xlsx', sheet_name='Sheet 1')

# %%
#print("Column headings:")
#print(df.columns)

# %%
x = [1.87,2.67,1.97,2.72,2.66,3.16,1.65,2.39,2.39,2.35,2.72,1.55,2.05,1.99,
     1.42,1.90,2.92,1.23,2.99,1.84,1.96,2.70,2.62,1.41,1.97,2.46,2.09,2.25,
     1.84,1.65,3.32,2.28,2.72,2.77,2.24,3.22,2.39,2.23,2.97,2.67,2.34,2.52,
     2.99,1.81,2.04,2.34,2.67,1.98,1.18,1.92]
x_theNine=[2.72,2.05,1.42,2.99,2.25,2.72,2.24,2.23,2.67]
num_bins = 8
num_bins2 = 6
plt.figure(figsize=(8,6))
n, bins, patches = plt.hist(x, num_bins, color='orange',alpha=0.4, edgecolor='black', linewidth=1)
n, bins, patches = plt.hist(x_theNine, num_bins2, color='w',hatch='xx', edgecolor='orange', linewidth=1,label='STARSMOG Nine')
plt.tick_params(labelsize=15)
plt.xlabel("u-r Color",fontsize=20)
plt.ylabel("Number of Foreground Galaxies",fontsize=20)
#plt.title("u-r Color of Foreground Galaxy",fontsize=20)
plt.legend(loc=2, borderaxespad=0.,fontsize=15)
plt.show()

# %% [markdown]
# Histogram of the u-r color of the foreground galaxy for our 55 overlapping galaxy pairs. The nine galaxy pairs to be inquired into are also indicated. This figure demonstrates the broad range of u-r color spanned by the STARSMOG sample. A galaxy's u-r color can be used as an indicator for star formation. Taking the difference between the magnitude in ultraviolet and magnitude in red. The value of u-r decreases with increasing light output.

# %%
x = [2.37,3.1,-0.26,3.12,3.16,3.6,1.84,2.76,2.76,2.79,3.14,1.76,2.44,2.32,
     3.05,2.21,3.35,1.36,3.42,2.01,2.29,3.1,2.99,1.65,2.19,2.68,2.52,2.68,
     2.01,2.71,3.83,2.64,3.18,3.2,2.62,3.76,2.77,2.58,5.25,3.15,2.86,2.9,
     3.42,2.11,2.41,2.71,3.05,2.27,1.46,2.30]
x_theNine = [3.12,2.44,3.05,3.42,2.68,3.18,2.62,2.58,3.15]
num_bins = 6
num_bins2 = 3
plt.figure(figsize=(8,6))
n, bins, patches = plt.hist(x, num_bins, color='k',alpha=0.4, edgecolor='black', linewidth=1)
n, bins, patches = plt.hist(x_theNine, num_bins2, color='w',hatch='xx', edgecolor='black', linewidth=1,label='STARSMOG Nine')
plt.tick_params(labelsize=15)
plt.xlabel("u-i Color",fontsize=20)
plt.ylabel("Number of Foreground Galaxies",fontsize=20)
#plt.title("u-i Color of Foreground Galaxy",fontsize=20)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
x = [108.0,101.2,16.0,548.0,152.0,128.0,452.0,64.0,104.0,64.0,160.0,96.0,118.4,157.2,27.6,168.4,174.4,292.4,490.8,
     15.2,400.0,41.6,123.6,120.4,170.8,23.2,40.8,86.0,708.0,138.0,62.4,181.2,171.6,90.8,124.4,67.2,205.6,544.0,
     286.4,27.2,190.4,153.6,127.2,105.6,137.2,164.0,23.6,108.0,55.2,110.8,58.8,54.8,494.5]
x_theNine = [152.0,157.2,168.4,400.0,138.0,124.4,205.6,27.2,127.2]
num_bins = 7
num_bins = 5
plt.figure(figsize=(8,6))
n, bins, patches = plt.hist(x, num_bins, color='purple',alpha=0.4, edgecolor='black', linewidth=1)
n, bins, patches = plt.hist(x_theNine, num_bins2, color='w',hatch='xx', edgecolor='purple', linewidth=1,label='STARSMOG Nine')
plt.tick_params(labelsize=15)
plt.xlabel("Distance (Mpc)",fontsize=20)
plt.ylabel("Number of Foreground Galaxies",fontsize=20)
#plt.title("Distance to Foreground Galaxy",fontsize=20)
plt.legend(loc=1, borderaxespad=0.,fontsize=15)
plt.show()

# %% [markdown]
# Histogram of the distance in Mpc of the foreground galaxy for our 55 overlapping galaxy pairs. The nine galaxy pairs to be inquired into are also indicated. This figure demonstrates the range of varying distance to the foreground galaxy spanned by the STARSMOG sample.

# %%
x=[22.22,7.83,17.54,22.57,16.75,8.21,7.43,5.74,11.39,11.01,26.27,25.17,3.54,16.25,43.77,
   12.89,20.74,20.07,13.59,7.32,12.43,13.82,8.32,10.84,18.19]
y = [0.508,0.407,0.206,0.111,0.061,0.294,0.462,0.154,1.051,0.338,0.147,0.295,0.060,0.091,
     0.448,0.128,0.155,0.395,0.165,0.200,0.304,0.766,0.834,0.026,0.905]
x_theNine=[22.22,5.74,16.25,20.07,13.59,13.82]
y_theNine=[0.508,0.154,0.091,0.395,0.165,0.766]
plt.figure(figsize=(8,6))
plt.plot(x, y,'ko')
plt.plot(x_theNine,y_theNine,'r*',label='STARSMOG Nine')
plt.tick_params(labelsize=15)
plt.xlabel("Disk Radius (arcsec)",fontsize=20)
plt.ylabel("OIII/Hb",fontsize=20)
#plt.title("Metallicity of Foreground Galaxy",fontsize=20)
plt.legend(loc=1, borderaxespad=0.,fontsize=15)
plt.show()

# %% [markdown]
# Scatter plot of the metallicity of the foreground galaxy for our 55 overlapping galaxy pairs. Six out of the nine galaxy pairs to be inquired into are also indicated. This figure demonstrates the broad range of metallicities spanned by the STARSMOG sample.

# %%
x = [0.508,0.407,0.206,0.111,0.061,0.294,0.462,0.154,1.051,0.338,0.147,0.295,0.060,0.091,
     0.448,0.128,0.155,0.395,0.165,0.200,0.304,0.766,0.834,0.026,0.905]
x_theNine = [0.508,0.154,0.091,0.395,0.165,0.766]
num_bins = 6
num_bins2 = 4
plt.figure(figsize=(8,6))
n, bins, patches = plt.hist(x, num_bins, color='indigo',alpha=0.4, edgecolor='black', linewidth=1)
n, bins, patches = plt.hist(x_theNine, num_bins2, color='w',hatch='xx', edgecolor='indigo', linewidth=1,label='STARSMOG Nine')
plt.tick_params(labelsize=15)
plt.xlabel("OIII/Hb",fontsize=20)
plt.ylabel("Number of Foreground Galaxies",fontsize=20)
#plt.title("Metallicity of Foreground Galaxy",fontsize=20)
plt.legend(loc=1, borderaxespad=0.,fontsize=15)
plt.show()

# %% [markdown]
# Histogram of the metallicity of the foreground galaxy for our 55 overlapping galaxy pairs. Six out of the nine galaxy pairs to be inquired into are also indicated. This figure demonstrates the broad range of metallicities spanned by the STARSMOG sample.

# %% [markdown]
# OIII/Hb values not available for 22 of our 55 overlapping galaxy pairs (foreground galaxy metallicity only). 3 of our 9 STARSMOG Nine pairs did not have metallicity values available. OIII and Hb values obtained from SDSS DR15.

# %%
x_E = [-21.28,-21.55]
y_E = [0.85,0.93]

x_Sa = [-21.40,-20.06,-22.00,-20.68,-21.69,-20.96,-20.19,-20.73,-20.97,
        -20.49,-21.31,-20.62,-21.30,-20.09,-19.87,-20.39,-21.72,-20.97,
        -21.02,-20.86,-21.27,-18.82]
y_Sa = [0.95,0.81,1.04,0.68,0.9,0.81,0.65,0.85,0.86,0.79,0.81,0.89,1.09,
        0.75,1,0.79,0.8,0.87,0.66,0.93,1.11,0.66]

x_Sc = [-21.83,-19.87,-19.71,-20.79,-20.33,-20.46,-19.51,-21.46,-21.88,
        -19.49,-18.82,-19.30,-19.93,-19.53,-19.21,-18.84,-18.79,
        -18.93,-18.88,-18.64,-23.27,-18.51,-19.01]
y_Sc = [0.85,0.7,0.61,0.57,0.81,0.66,0.83,0.8,0.71,0.38,0.73,0.61,
        0.75,0.44,0.92,0.54,0.63,0.87,0.39,0.49,0.89,0.5,0.3]

plt.plot(x_E,y_E,'bo',label='E')
plt.plot(x_Sa,y_Sa,'ys',label='Sa-Sbc')
plt.plot(x_Sc,y_Sc,'rD',label='Sc-Sm')
plt.tick_params(labelsize=15)
plt.xlabel("$M_r$",fontsize=20)
plt.ylabel("g-r",fontsize=20)
#plt.title("Color Magnitude Diagram",fontsize=20)
plt.legend(loc=3, borderaxespad=0.,fontsize=15)
plt.show()

# %% [markdown]
# Color-magnitude diagram of the foreground galaxy for our 55 overlapping galaxy pairs coded by morphological type: E (blue points), Sa-Sbc (yellow squares), and Sc-Sm (red diamonds). For comparison, the contoured greyscale image shows the color-magnitude diagram of a flux-limited sample of ~5x10^5 SDSS galaxies. This figure demonstrates the broad range of optical luminosity and color spanned by the STARSMOG sample.

# %%
x=[22.22,10.05,7.66,5.74,16.25,20.07,13.59,13.4,13.82]
y=[0.1865199,0.49196643,0.4166539,0.10840871,0.13763343,
   0.70668554,0.1438766,0.702335,0.5108565]
plt.plot(x,y,'ko')
plt.xlabel("$R_p$ (arcsec)",fontsize=20)
plt.ylabel("Optical Depth",fontsize=20)
plt.show()
